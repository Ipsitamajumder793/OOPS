# %%
# THEORY QUESTIONS (OOPS) #
'''

    1. What is object oriented programming oops?
    
        Ans:- 
     Object-oriented programming (OOP) is a programming paradigm that organizes software design around objects, which are data-driven entities with
     unique attributes and behaviors. It focuses on manipulating these objects rather than the underlying logic, offering benefits like code reusability,
     scalability, and maintainability. OOP uses concepts like classes, objects, inheritance, polymorphism, and encapsulation to structure code.
    
    
    
    2. What is the class in OOPS?
       Ans:-
            In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the properties (variables) 
            and behaviors (methods) that objects of that class will possess. Essentially, a class is a user-defined data type that describes
            the structure and functionality of a group of related objects. 
    
    
    3. What is an object in OOP ?
    Ans:-
            In Object-Oriented Programming (OOP), an object is a fundamental unit that represents a real-world entity or concept with its own
            attributes (data) and behaviors (methods). It's essentially a bundle of related data and functions that act on that data, allowing
            for a more organized and modular approach to software development. 
    
    
    4. What is the difference between abstraction and encapsulation?
        Ans:-
            Abstraction focuses on what an object does, hiding unnecessary implementation details and exposing only essential functionalities.
            Encapsulation, on the other hand, focuses on how an object does it, bundling data and methods into a single unit and restricting 
            direct access to protect data integrity.
    
    5. What is dunder method in Python?
     Ans:-
           Dunder methods, also known as magic methods, are special methods in Python that begin and end with double underscores 
           (e.g., __init__, __str__, __len__). They allow classes to define how they behave with built-in functions and operators. 
           For example, the __init__ method is a constructor that initializes an object's attributes when it is created. 
           Another example is __str__, which defines how an object should be represented as a string. Dunder methods enable operator overloading, 
           allowing custom classes to work with operators like +, -, *, [], etc.
    
    
    6. Explain the concept of inheritance in OOPS. 
         Ans:-
            Inheritance in Object-Oriented Programming (OOP) is a mechanism where a class (called the derived or child class) can inherit 
            properties and behaviors from another class (the base or parent class). This allows for code reuse and establishes a hierarchical
            relationship between classes, making it easier to create specialized classes from more general ones. 
    
    
    7. What is polymorphism in OOPS? 
        Ans:-
            In Object-Oriented Programming (OOP), polymorphism, meaning "many forms," allows objects of different classes to be treated as if
            they belong to a common type. It enables a single interface (like a method name) to represent different actions or operations, 
            making code more flexible and reusable. This is achieved through concepts like method overloading and overriding,
            allowing the same method name to perform different tasks based on the object's specific class. 
    
    8. How encapsulation is achieved in Python? 
    Ans:- 
            In Python, encapsulation refers to the bundling of data (attributes) and methods (functions) that operate on the data into 
            a single unit, typically a class. It also restricts direct access to some components, which helps protect the integrity of the
            data and ensures proper usage.
    
    E.g.
    class Public:
        def __init__(self):
            self.name = "John"  # Public attribute
    
        def display_name(self):
            print(self.name)  # Public method
    
    obj = Public()
    obj.display_name()
    print(obj.name) 
    
    9. What is constructor in Python? 
    Ans:-
            A constructor in Python is a special method used to initialize objects of a class. It is automatically called when an object
            is created. The constructor is defined using the __init__ method. It takes self as its first argument, which refers to the instance
            of the class being created, and can take additional arguments to initialize the object's attributes. 
    
    E.g.
    
    class Dog:
        def __init__(self, name, breed):
            self.name = name
            self.breed = breed
    
    my_dog = Dog("Buddy", "Golden Retriever")
    print(my_dog.name)
    print(my_dog.breed)
    
    
    10. What are classes and static methods in Python?
    Ans:- 
            Classes in Python serve as blueprints for creating objects, encapsulating data (attributes) and behavior (methods) into a single unit.
            They facilitate code organization, reusability, and the implementation of object-oriented programming principles.
            Static methods, on the other hand, are methods bound to the class and not the instance of the class.
            They do not have access to the instance-specific data or class-specific data, and are primarily used for utility functions that
            don't depend on the state of the object or class. They are defined using the @staticmethod decorator. 
    
    E.g.
    
    class MyClass:
        class_variable = "Class Variable"
    
        def __init__(self, instance_variable):
            self.instance_variable = instance_variable
    
        def instance_method(self):
            return f"Instance variable: {self.instance_variable}"
    
        @classmethod
        def class_method(cls):
            return f"Class variable: {cls.class_variable}"
    
        @staticmethod
        def static_method(arg1, arg2):
            return f"Static method result: {arg1 + arg2}"
    
      11. What is method overloading in Python? 
    
             Ans:-
             Method overloading in Python refers to the ability to define multiple methods within the same class that share a name but have 
             distinct parameter lists. This allows a single method name to perform different actions based on the number or types of arguments
             passed to it. While Python doesn't natively support method overloading in the same way as languages like Java or C++, it achieves 
             similar functionality through techniques like default arguments and variable-length argument lists (*args and **kwargs). 
    
    E.g.
    
      class Calculator:
        def add(self, a, b, c=0):
            return a + b + c
    
    calc = Calculator()
    print(calc.add(5, 10))  # Output: 15
    print(calc.add(5, 10, 20)) # Output: 35
    
    12. What is method overriding in Python? 
      Ans:-
           Method overriding in Python is a feature of object-oriented programming where a subclass provides a specific implementation for a 
           method that is already defined in its superclass. When a method in a subclass has the same name, parameters, and return type as a method
           in its superclass, the method in the subclass overrides the method in the superclass. This allows a subclass to customize or extend the 
           behavior of an inherited method without modifying the original class. 
    E.g.
    
    class Shape:
        def area(self):
            return "Area of shape"
     
    class Circle(Shape):
        def __init__(self, radius):
            self.radius = radius
        
        def area(self):
            return 3.14 * self.radius * self.radius
    
    class Square(Shape):
        def __init__(self, side):
            self.side = side
        
        def area(self):
            return self.side * self.side
    
    circle = Circle(5)
    square = Square(4)
    
    print(circle.area()) # Output: 78.5
    print(square.area()) # Output: 16
    
    
    13. What is the property decorator in Python? 
    Ans:-
           The @property decorator in Python is a built-in feature that allows methods to be accessed like attributes. It provides a way to
           encapsulate the logic for getting, setting, and deleting an attribute within a class, without requiring the user to call getter
           and setter methods directly. This enhances code readability and maintainability.
          The @property decorator is used to define the "getter" method for an attribute. Additional decorators, @attribute.setter and
          @attribute.deleter, can be used to define the "setter" and "deleter" methods, respectively. These methods are automatically called
          when the attribute is accessed, assigned a value, or deleted, respectively.
    
    E.g.
    class MyClass:
        def __init__(self, value):
            self._value = value
    
        @property
        def value(self):
            """Getter method for the value attribute."""
            return self._value
    
        @value.setter
        def value(self, new_value):
            """Setter method for the value attribute."""
            if new_value < 0:
                raise ValueError("Value cannot be negative")
            self._value = new_value
    
        @value.deleter
        def value(self):
            """Deleter method for the value attribute."""
            del self._value
    
    # Example usage
    obj = MyClass(10)
    print(obj.value)  # Accessing the attribute using the getter
    obj.value = 20  # Assigning a value using the setter
    print(obj.value)
    del obj.value  # Deleting the attribute using the deleter
    
    
    
    14. Why is polymorphism important in OOPS? 
       Ans:-
           Polymorphism is vital in Object-Oriented Programming (OOP) because it enables different classes to share the same interface while
           maintaining their unique behaviors. This promotes code reusability, allows for a single method name to be used across multiple classes,
           and supports the creation of a more flexible and extensible codebase. 
    
    Code Reusability:
    Polymorphism allows objects of different classes to be treated as objects of a common superclass or interface, enabling the same code to be used
    for various objects with shared behaviors. 
    Flexibility and Extensibility:
    By designing code to work with a common interface, you can add new subclasses without modifying existing methods, making the system more flexible
    and adaptable. 
    Simplified Implementation:
    Polymorphism simplifies the implementation by allowing you to interact with objects of different types through a single, common interface. 
    Abstraction:
    Polymorphism allows you to hide the complexity of different object implementations and focus on the common interface, promoting abstraction. 
    Efficiency and Adaptability:
    Polymorphism leads to efficient software development by promoting the use of a single method name to invoke the correct method for a given class,
    and it also allows for efficient adaptation to changing requirements. 
    Dynamic Method Dispatch:
    Polymorphism enables dynamic method dispatch, where the method to be executed is determined at runtime based on the object's actual type,
    not its reference type. 
    In essence, polymorphism allows for more maintainable, reusable, and flexible code, making it a cornerstone of true object-oriented programming. 
    
    15. What is an abstract class in Python? 
    Ans:-
            An abstract class in Python serves as a blueprint for other classes, defining a common interface while allowing subclasses to provide 
            specific implementations. It cannot be instantiated directly and often contains abstract methods, which are declared but not implemented 
            in the abstract class itself. Subclasses are then required to provide concrete implementations for these abstract methods.
    To create an abstract class in Python, the abc module (Abstract Base Classes) is used. The ABC class is inherited, and the @abstractmethod decorator
    is applied to methods that must be implemented by subclasses. Attempting to instantiate an abstract class or a subclass that doesn't implement all
    abstract methods will result in a TypeError. 
    Abstract classes enforce a common structure and ensure that subclasses adhere to a specific interface, promoting consistency and reliability
    in code. They facilitate code reusability, encourage organized code, and enhance flexibility by allowing the introduction of new derived classes 
    without modifying existing code.
    E.g.
    
    from abc import ABC, abstractmethod
    
    class Shape(ABC):
        @abstractmethod
        def area(self):
            pass
    
        @abstractmethod
        def perimeter(self):
            pass
    
    class Rectangle(Shape):
        def __init__(self, length, width):
            self.length = length
            self.width = width
    
        def area(self):
            return self.length * self.width
    
        def perimeter(self):
            return 2 * (self.length + self.width)
    
    class Circle(Shape):
        def __init__(self, radius):
            self.radius = radius
    
        def area(self):
            return 3.14159 * self.radius * self.radius
    
        def perimeter(self):
            return 2 * 3.14159 * self.radius
    
    # Attempting to instantiate Shape would raise a TypeError
    # shape = Shape() 
    
    rectangle = Rectangle(5, 10)
    print(f"Rectangle area: {rectangle.area()}")
    print(f"Rectangle perimeter: {rectangle.perimeter()}")
    
    circle = Circle(7)
    print(f"Circle area: {circle.area()}")
    print(f"Circle perimeter: {circle.perimeter()}")
    
    
    16. What are advantages of oops?
    Ans:-
    *Advantages of Object-Oriented Programming* 
    
    Offers Security.
    Improves Collaboration.
    Allows Reuse of Code.
    Makes Changes Seamlessly.
    Locates and Fixes Problems Effortlessly.
    Ensures Flexibility.
    Drives Productivity.
    Maintains Code Consistently.
    
    17. Difference between class variable and instance variable?
       Ans:-
              The differences between class variables and instance variables in Python are: 
    Scope:
    Class variables are defined within the class but outside of any methods, and they are shared among all instances of the class. 
    Instance variables are defined within methods, typically within the __init__ method, and they are unique to each instance of the class.
    Access:
    Class variables can be accessed using the class name or an instance of the class. Instance variables can only be accessed using an instance 
    of the class. 
    Modification:
    Modifying a class variable affects all instances of the class. Modifying an instance variable only affects that specific instance.
    Use cases:
    Class variables are suitable for storing data that is shared among all instances of a class, such as constants or counters. Instance variables
    are suitable for storing data that is specific to each instance, such as attributes or states.
    
    18. What is multiple inheritance in Python? 
    Ans:-
            Multiple inheritance in Python is a feature where a class can inherit attributes and methods from more than one parent class.
            This allows a class to incorporate functionalities from different sources, creating a more versatile and feature-rich class.
            When a class inherits from multiple parent classes, it gains access to all the attributes and methods of those parent classes. 
    E.g.
    class Parent1:
        def method_1(self):
            return "Method from Parent1"
    
    class Parent2:
        def method_2(self):
            return "Method from Parent2"
    
    class Child(Parent1, Parent2):
        pass
    
    child_object = Child()
    print(child_object.method_1())
    print(child_object.method_2())
    
    19. Explain the purpose of __str__ and __repr__ methods in Python.
        Ans:-
            __str__ is used for informal string representations, such as printing objects for user consumption. __repr__ is used for formal string
            representations, including debugging, logging, and object inspection
    
    __repr__() returns the official string representation, which is aimed at programmers as they develop and maintain a program. 
    The special method . __str__() returns the informal string representation, a friendlier format for the program's user.
    
    20. What is the significance of super() function in Python?
    Ans:-
           The super() function in Python is used to call methods from a parent class in a subclass. It provides a way to access and utilize
           the functionality of the superclass, promoting code reuse and maintainability. It is particularly useful in the context of inheritance,
           where a subclass inherits attributes and methods from a parent class. 
    super() returns a temporary object of the superclass, allowing access to its methods. By using super(), the explicit name of the parent class
    does not need to be specified, making the code more flexible and adaptable to changes in the inheritance hierarchy. This is especially beneficial
    when working with multiple inheritance. 
    A common use case for super() is within the __init__() method of a subclass. When a subclass needs to initialize attributes inherited from the
    parent class, super().__init__() can be called to execute the initialization logic of the parent class. This ensures that the parent class's
    attributes are properly initialized before any subclass-specific attributes are added.
    
    E.g.
    class Parent:
        def __init__(self, name):
            self.name = name
    
        def display(self):
            print(f"Name: {self.name}")
    
    class Child(Parent):
        def __init__(self, name, age):
            super().__init__(name)
            self.age = age
    
        def display(self):
            super().display()
            print(f"Age: {self.age}")
    
    child = Child("Alice", 10)
    child.display()
    # Output:
    # Name: Alice
    # Age: 10
    
    
    21. What is the significance of __del__  method in Python?
    Ans:-
           The __del__ method in Python, often referred to as a destructor, is called when an object is garbage collected, meaning it's about to be 
           destroyed because there are no more references to it. Its primary significance lies in performing cleanup actions, such as releasing
           external resources held by the object.
    When an object is no longer needed, Python's garbage collector reclaims the memory it occupied. Before doing so, it invokes the __del__ method,
    giving the object a final chance to tidy up. This can involve closing files, disconnecting from network connections, or releasing any 
    other external resources that the object might have acquired.
    However, relying heavily on __del__ is generally discouraged due to its unpredictable timing. The garbage collector's behavior is not 
    deterministic, and __del__ might not be called immediately when an object is no longer in use, or even at all in some cases. 
    For more reliable resource management, it's recommended to use context managers (with statement) or explicit close() methods.
    
    22. What is the difference between @static method and @ class method in Python? 
    Ans:-
            Here is the difference between @staticmethod and @classmethod in Python:
    @staticmethod:
    It is a function defined inside a class but does not have access to the instance (self) or the class (cls).
    It behaves like a regular function, but is namespaced within the class.
    It cannot modify class state.
    It is used for utility functions that are logically related to the class but do not depend on its specific instances or class-level attributes.
    @classmethod:
    It is a method bound to the class and not the instance of the class. 
    It receives the class itself as the first argument (cls).
    It can access and modify class-level attributes.
    It can be used as an alternative constructor or to perform operations that involve the class itself.
    
    23. How does polymorphism work in Python with inheritance? 
    Ans:-
           Polymorphism in Python, in the context of inheritance, allows objects of different classes to be treated as objects of a common type.
           This is achieved through method overriding, where a subclass provides a specific implementation for a method that is already defined
           in its parent class. When a method is called on an object, Python determines the appropriate method to execute based on the object's
           actual type at runtime.
    E.g.
    class Animal:
        def speak(self):
            return "Generic animal sound"
    
    class Dog(Animal):
        def speak(self):
            return "Woof!"
    
    class Cat(Animal):
        def speak(self):
            return "Meow!"
    
    animals = [Dog(), Cat(), Animal()]
    for animal in animals:
        print(animal.speak())
    
    24. What is method changing in Python OOP?
    Ans:-
           Method chaining in Python is a programming technique used in object-oriented programming. It allows multiple methods to be called
           sequentially on the same object in a single line of code. This is achieved by having each method in the chain return the object 
           itself (i.e., self).
    To implement method chaining, each method in a class should return self after performing its operation. This allows the next method in the 
    chain to be called directly on the result of the previous method.
    E.g.
    class MyClass:
        def __init__(self, value):
            self.value = value
    
        def add(self, num):
            self.value += num
            return self
    
        def subtract(self, num):
            self.value -= num
            return self
    
        def multiply(self, num):
            self.value *= num
            return self
    
    # Usage
    obj = MyClass(10)
    result = obj.add(5).subtract(3).multiply(2)
    print(result.value)  # Output: 24
    
    25. What is the purpose of the __call__method in Python?
    Ans:-
          The __call__ method in Python enables instances of a class to be called like regular functions. When a class defines the __call__ method, 
          its instances become callable objects. This allows for more flexible and expressive code, as objects can encapsulate state and behavior
          while still being invoked directly.
    When an instance obj of a class with a __call__ method is "called" like a function, such as obj(arg1, arg2, ...), Python automatically invokes
    the __call__ method defined within the class, passing the arguments provided during the "call" to the method. This mechanism effectively
    transforms the object into a callable entity, similar to a function.
    E.g.
    class Example:
        def __init__(self, name):
            self.name = name
    
        def __call__(self, greeting):
            return f"{greeting}, {self.name}!"
    
    obj = Example("Alice")
    message = obj("Hello")
    print(message)  # Output: Hello, Alice!

'''

# %%
# PRACTICAL QUESTIONS OOPS:: #
# 1. Create a parent class animal with a method speak that prints a generic message created child class dog that override the speak method to print bark! .#
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

#Example Usage
animal = Animal()
dog = Dog()

animal.speak() # Output: Generic animal sound
dog.speak()    # Output: Bark!
# Out:
# Generic animal sound
# Bark!

# %%
# 2. Write a program to create an abstract class shape with a method area(). Derive classes circle and rectangle from it and implement the area( ) method in both.#
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return math.pi * self.radius**2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width

# Example Usage
circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Area of circle:", circle.area())
print("Area of rectangle:", rectangle.area())
# Out:
# Area of circle: 78.53981633974483
# Area of rectangle: 24

# %%
# 3. Implement a multi level inheritance scenario where a class vehicle has an attribute type. Derive a class car and further derive a class ElectricCar that adds a battery attribute. #
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, num_doors):
        super().__init__(type)
        self.num_doors = num_doors

class ElectricCar(Car):
    def __init__(self, type, num_doors, battery_capacity):
        super().__init__(type, num_doors)
        self.battery_capacity = battery_capacity

#Example Usage
vehicle = Vehicle("generic")
car = Car("sedan", 4)
electric_car = ElectricCar("hatchback", 4, "60 kWh")

print(f"Vehicle type: {vehicle.type}")
print(f"Car type: {car.type}, Number of doors: {car.num_doors}")
print(f"Electric car type: {electric_car.type}, Number of doors: {electric_car.num_doors}, Battery capacity: {electric_car.battery_capacity}")
# Out:
# Vehicle type: generic
# Car type: sedan, Number of doors: 4
# Electric car type: hatchback, Number of doors: 4, Battery capacity: 60 kWh

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly (). Create two derived classes sparrow & penguin that override the fly( ) method #
class Bird:
    def fly(self):
        return "Birds can generally fly."

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        return "Sparrows fly in the sky."

# Derived class 2
class Penguin(Bird):
    def fly(self):
        return "Penguins cannot fly, but they can swim."

# Function demonstrating polymorphism
def bird_fly(bird):
    return bird.fly()

# Creating instances of the derived classes
sparrow = Sparrow()
penguin = Penguin()

# Using the polymorphic method
print(bird_fly(sparrow))
print(bird_fly(penguin))
# Out:
# Sparrows fly in the sky.
# Penguins cannot fly, but they can swim.

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit withdraw and check balance #
class Bank_Account:
    def __init__(self):
        self.balance=0
        print("Hello!!! Welcome to the Deposit & Withdrawal Machine")
 
    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.balance += amount
        print("\n Amount Deposited:",amount)
 
    def withdraw(self):
        amount = float(input("Enter amount to be Withdrawn: "))
        if self.balance>=amount:
            self.balance-=amount
            print("\n You Withdrew:", amount)
        else:
            print("\n Insufficient balance  ")
 
    def display(self):
        print("\n Net Available Balance=",self.balance)
 
# Driver code
  
# creating an object of class
s = Bank_Account()
  
# Calling functions with that class object
s.deposit()
s.withdraw()
s.display()
# Out:
# Hello!!! Welcome to the Deposit & Withdrawal Machine
# Enter amount to be Deposited:  100
#  Amount Deposited: 100.0
# Enter amount to be Withdrawn:  100
#  You Withdrew: 100.0
#
#  Net Available Balance= 0.0

# %%
# 6. Demonstrate runtime polymorphism using a method play in a base class instrument. Derive classes guitar and piano that implement their own version of play ().#
class Instrument:
    def play(self):
        print("Generic instrument sound")

class Guitar(Instrument):
    def play(self):
        print("Strumming guitar strings")

class Piano(Instrument):
    def play(self):
        print("Playing piano keys")

def instrument_sound(instrument):
    instrument.play()

if __name__ == "__main__":
    instrument = Instrument()
    guitar = Guitar()
    piano = Piano()

    instrument_sound(instrument) # Output: Generic instrument sound
    instrument_sound(guitar)     # Output: Strumming guitar strings
    instrument_sound(piano)      # Output: Playing piano keys
# Out:
# Generic instrument sound
# Strumming guitar strings
# Playing piano keys

# %%
# 7. Create a class MathOperations with the class method add_number() to add two numbers and static method subtract_numbers() to subtract two numbers #
class MathOperations:
    @classmethod
    def add_numbers(cls, x, y):
        return x + y

    @staticmethod
    def subtract_numbers(x, y):
        return x - y

result_add = MathOperations.add_numbers(5, 3)
print(f"The sum is: {result_add}")

result_subtract = MathOperations.subtract_numbers(10, 4)
print(f"The difference is: {result_subtract}")
# Out:
# The sum is: 8
# The difference is: 6

# %%
# 8. Implement a class Person with a class method to count the total number of persons created. #
class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

# Example usage
person1 = Person()
person2 = Person()
person3 = Person()

print(f"Total persons created: {Person.get_count()}")
# Out:
# Total persons created: 3

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as numerator/denominator.  #
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage:
fraction1 = Fraction(3, 4)
print(fraction1)  # Output: 3/4

fraction2 = Fraction(1, 2)
print(fraction2) # Output 1/2
# Out:
# 3/4
# 1/2

# %%
# 10. Demonstrate operator overloading by creating a class vector and overriding the add method to add two vectors.    #
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Unsupported operand type for +: Vector and {}".format(type(other).__name__))

    def __str__(self):
        return "({}, {})".format(self.x, self.y)

# Example usage
v1 = Vector(2, 3)
v2 = Vector(5, -1)

v3 = v1 + v2
print(v3)

try:
    v4 = v1 + 5
except TypeError as e:
    print(e)
# Out:
# (7, 2)
# Unsupported operand type for +: Vector and int

# %%
# 11. Create a class person with attributes name and age. Add a method greet() that prints "Hello ,my name is {name} and I am {age} years old." #
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
person1 = Person("Alice", 30)
person1.greet()

person2 = Person("Bob", 25)
person2.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.
# Hello, my name is Bob and I am 25 years old.

# %%
# 12. Implement a class student with attributes name and grades. Create a method average_grade() to  compute the average of the grades. #
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return None  # Avoid division by zero
        return sum(self.grades) / len(self.grades)

# Example usage:
student1 = Student("Alice", [85, 92, 78, 95])
avg_grade = student1.average_grade()

if avg_grade is not None:
    print(f"The average grade for {student1.name} is: {avg_grade}")
else:
    print(f"{student1.name} has no grades to average.")

student2 = Student("Bob", []) # Example with an empty grades list
avg_grade = student2.average_grade()

if avg_grade is not None:
    print(f"The average grade for {student2.name} is: {avg_grade}")
else:
    print(f"{student2.name} has no grades to average.")
# Out:
# The average grade for Alice is: 87.5
# Bob has no grades to average.

# %%
# 13. Create a class rectangle with methods set_dimensions( ) to set the dimensions and area() to calculate the area#
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on our worked and hourly rate. Create a derived class Manager that add a bonus to the salary.     #
class Employee:
    def __init__(self, name, hourly_rate, hours_worked):
        self.name = name
        self.hourly_rate = hourly_rate
        self.hours_worked = hours_worked

    def calculate_salary(self):
        return self.hourly_rate * self.hours_worked

class Manager(Employee):
    def __init__(self, name, hourly_rate, hours_worked, bonus):
        super().__init__(name, hourly_rate, hours_worked)
        self.bonus = bonus

    def calculate_salary(self):
        salary = super().calculate_salary()
        return salary + self.bonus

# Example Usage
employee = Employee("John Doe", 25.00, 40)
manager = Manager("Jane Doe", 35.00, 40, 1000)

print(f"Employee {employee.name}'s salary: ${employee.calculate_salary()}")
print(f"Manager {manager.name}'s salary: ${manager.calculate_salary()}")
# Out:
# Employee John Doe's salary: $1000.0
# Manager Jane Doe's salary: $2400.0

# %%
# 15. Create a class Product with attributes name,price and quantity. Implement a method total_price( ) that calculate the total price of the product    #
class Product:
    def __init__(self, name, price, quantity):
        """
        Initializes a Product object.
        
        Args:
            name (str): The name of the product.
            price (float): The price of the product per unit.
            quantity (int): The quantity of the product.
        """
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def total_price(self):
         """
         Calculates the total price of the product.
         
         Returns:
             float: The total price of the product (price * quantity).
         """
         return self.price * self.quantity

# Example usage
product1 = Product("Laptop", 1200.00, 5)
product2 = Product("Mouse", 25.00, 10)

print(f"{product1.name} total price: ${product1.total_price()}")
print(f"{product2.name} total price: ${product2.total_price()}")
# Out:
# Laptop total price: $6000.0
# Mouse total price: $250.0

# %%
# 16. Create a class Animal with an abstract method sound (). Create two derived classes Cow and Sheep that implement the sound( ) method. #
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

# Example usage
cow = Cow()
print(cow.sound())  # Output: Moo

sheep = Sheep()
print(sheep.sound())  # Output: Baa
# Out:
# Moo
# Baa

# %%
#17. Create a class Book with attributes title, author and year_published . #
#Add a method get_book_info() that returns a formatted string with the book's details#
class Book:
    def __init__(self,title,author,year_published):
        self.title=title
        self.author=author
        self.year_published=year_published
    def get_book_info(self):
         ret=f"Book Title is {self.title} and author is {self.author} and year_published is {self.year_published}"
         return ret
        
b1=Book("The Ramayana","Hrishi Balmiki","30/10/1979")
print(b1.get_book_info())
# Out:
# Book Title is The Ramayana and author is Hrishi Balmiki and year_published is 30/10/1979

# %%
#18. Create a class House with attributes address and price. Create a derived class mention that adds and attribute number_of_rooms#
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mention(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
